# %% [markdown]
# # Training Model ETL

# %% [markdown]
# ### Extract CSV

# %%
import pandas as pd

# %%
df = pd.read_csv("readings.csv")

# %% [markdown]
# ### Display the dataset

# %%
df
# Out:
#       id  batch_id   gravity  temperature   battery     angle  \
# 0      1         1  1.015740      30.1875  4.056309  31.13034
# 1      2         1  1.014763      30.1875  4.056309  30.65194
# 2      3         1  1.013954      30.1250  4.056309  30.26313
# 3      4         1  1.013093      30.0625  4.056309  29.85785
# 4      5         1  1.013142      30.0625  4.056309  29.88073
# ..   ...       ...       ...          ...       ...       ...
# 943  944         1  0.999194      26.1875  3.889468  24.21739
# 944  945         1  0.999150      26.1875  3.889468  24.20172
# 945  946         1  0.999208      26.1875  3.889468  24.22255
# 946  947         1  0.999159      26.1875  3.889468  24.20502
# 947  948         1  0.999195      26.1875  3.884254  24.21764
#
#                       timestamp      brix
# 0    2025-10-06T16:08:45.513729  4.012791
# 1    2025-10-06T16:08:58.411916  3.766628
# 2    2025-10-06T16:09:10.999436  3.562475
# 3    2025-10-06T16:09:23.931160  3.344882
# 4    2025-10-06T16:09:39.360793  3.357274
# ..                          ...       ...
# 943  2025-10-07T09:01:09.982037 -0.213538
# 944  2025-10-07T09:02:12.577656 -0.224941
# 945  2025-10-07T09:02:12.593633 -0.209909
# 946  2025-10-07T09:02:19.263649 -0.222609
# 947  2025-10-07T09:02:31.954492 -0.213278
#
# [948 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 948 entries, 0 to 947
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           948 non-null    int64
#  1   batch_id     948 non-null    int64
#  2   gravity      948 non-null    float64
#  3   temperature  948 non-null    float64
#  4   battery      948 non-null    float64
#  5   angle        948 non-null    float64
#  6   timestamp    948 non-null    object
#  7   brix         948 non-null    float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 59.4+ KB

# %%
df.describe()
# Out:
#                id  batch_id     gravity  temperature     battery       angle  \
# count  948.000000     948.0  948.000000   948.000000  948.000000  948.000000
# mean   474.500000       1.0    1.002666    28.109968    4.004149   25.569460
# std    273.808327       0.0    0.004715     1.028162    0.053262    1.857059
# min      1.000000       1.0    0.998079    26.187500    3.863399   23.825360
# 25%    237.750000       1.0    0.998767    27.500000    3.983316   24.066267
# 50%    474.500000       1.0    0.999198    28.625000    4.035453   24.218870
# 75%    711.250000       1.0    1.005876    28.937500    4.045881   26.737265
# max    948.000000       1.0    1.015740    30.187500    4.056309   31.130340
#
#              brix
# count  948.000000
# mean     0.678422
# std      1.210512
# min     -0.502790
# 25%     -0.324242
# 50%     -0.212371
# 75%      1.507973
# max      4.012791

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Remove the unnecessary columns

# %%
df = df.drop(columns=["id", "batch_id", "battery", "angle"])

# %% [markdown]
# ### Remove the rows after 3 days

# %%
df
# Out:
#       gravity  temperature                   timestamp      brix
# 0    1.015740      30.1875  2025-10-06T16:08:45.513729  4.012791
# 1    1.014763      30.1875  2025-10-06T16:08:58.411916  3.766628
# 2    1.013954      30.1250  2025-10-06T16:09:10.999436  3.562475
# 3    1.013093      30.0625  2025-10-06T16:09:23.931160  3.344882
# 4    1.013142      30.0625  2025-10-06T16:09:39.360793  3.357274
# ..        ...          ...                         ...       ...
# 943  0.999194      26.1875  2025-10-07T09:01:09.982037 -0.213538
# 944  0.999150      26.1875  2025-10-07T09:02:12.577656 -0.224941
# 945  0.999208      26.1875  2025-10-07T09:02:12.593633 -0.209909
# 946  0.999159      26.1875  2025-10-07T09:02:19.263649 -0.222609
# 947  0.999195      26.1875  2025-10-07T09:02:31.954492 -0.213278
#
# [948 rows x 4 columns]

# %% [markdown]
# ### Load

# %%
df.to_csv("transform_readings.csv", index=False)

# %% [markdown]
# ### Modeling

# %% [markdown]
# ### LSTM

# %%
pip install tensorflow scikit-learn pandas matplotlib
# Out:
# Requirement already satisfied: tensorflow in c:\users\miggy\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: scikit-learn in c:\users\miggy\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: pandas in c:\users\miggy\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\miggy\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\miggy\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\miggy\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\miggy\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\miggy\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\miggy\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\miggy\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\miggy\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\miggy\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\miggy\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\miggy\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\miggy\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\miggy\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\miggy\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\miggy\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\miggy\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\miggy\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in c:\users\miggy\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\miggy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\miggy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\miggy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\miggy\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\miggy\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\miggy\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\miggy\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\miggy\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\miggy\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\miggy\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\miggy\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("transform_readings.csv")

# %%
df.head()
# Out:
#     gravity  temperature                   timestamp      brix
# 0  1.015740      30.1875  2025-10-06T16:08:45.513729  4.012791
# 1  1.014763      30.1875  2025-10-06T16:08:58.411916  3.766628
# 2  1.013954      30.1250  2025-10-06T16:09:10.999436  3.562475
# 3  1.013093      30.0625  2025-10-06T16:09:23.931160  3.344882
# 4  1.013142      30.0625  2025-10-06T16:09:39.360793  3.357274

# %%
# Convert Brix to Specific Gravity
df['gravity'] = (df['brix'] / (258.6 - ((df['brix'] / 258.2) * 227.1))) + 1

# Compute Alcohol Content using your given formula
df['Alcohol_Content'] = (((182.4601 * df['gravity'] - 775.6821) * df['gravity'] + 1262.7794) * df['gravity'] - 669.5622)

# Display new columns
df[['timestamp', 'brix', 'temperature', 'Alcohol_Content']].head()
# Out:
#                     timestamp      brix  temperature  Alcohol_Content
# 0  2025-10-06T16:08:45.513729  4.012791      30.1875         4.010799
# 1  2025-10-06T16:08:58.411916  3.766628      30.1875         3.764479
# 2  2025-10-06T16:09:10.999436  3.562475      30.1250         3.560194
# 3  2025-10-06T16:09:23.931160  3.344882      30.0625         3.342460
# 4  2025-10-06T16:09:39.360793  3.357274      30.0625         3.354860
